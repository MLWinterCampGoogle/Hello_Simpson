# %%
from IPython.display import Image

PATH1 = 'data/simpson440/simplified/'
Image(filename = PATH1 + '1001.png')

# %%
PATH2 = 'data/simpson440/cropped/'
Image(filename = PATH2 + '1001.png')

# %%
PATH3 = 'data/simpson1k/simpsons_dataset/simpsons_dataset/lenny_leonard/'

Image(filename = PATH3 + 'pic_0001.jpg')

# %%
PATH4 = 'data/simpson1k/simpsons_dataset/abraham_grampa_simpson/'

Image(filename = PATH4 + 'pic_0000.jpg')

# %%
PATH5 = 'data/human/matting/1803151818/matting_00000010/1803151818-00010018.png'

Image(filename = PATH5)

# %%
PATH6 = 'data/human/matting_human_half/clip_img/1803151818/clip_00000010/1803151818-00010002.jpg'

Image(filename = PATH6)
